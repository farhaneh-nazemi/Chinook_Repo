# %% [markdown]
# Import libraries

# %%
import json
from mysql.connector import errorcode
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sqlalchemy import create_engine, inspect
from scipy.stats import shapiro, kstest, normaltest, probplot,zscore,f_oneway,kruskal,pearsonr,chi2_contingency
from datetime import datetime
import scipy.stats as stats
import os

# %%
GREEN = "\033[32m"
RESET = "\033[0m"
image_dir = os.path.join("..", "reports","figures", "plot_image")

# %% [markdown]
# # Question 1.

# %% [markdown]
# Create the SQLAlchemy engine

# %%
with open("../references/db_config.json", 'r') as configfile:
    db_config=json.load(configfile)

engine = create_engine(f"mysql+mysqlconnector://{db_config['user']}:{db_config['password']}@{db_config['host']}:{db_config['port']}/{db_config['database']}")

# %% [markdown]
# Load each table into a Dictionary

# %%
# Initialize the inspector to get table names
inspector = inspect(engine)
tables = inspector.get_table_names()

# Dictionary to hold the DataFrames
dataframes = {}
for table_name in tables:
    df = pd.read_sql(f"SELECT * FROM {table_name}", engine)
    dataframes[table_name] = df

# %% [markdown]
# Load tables into a separate DataFrame

# %%
album = dataframes['album']
artist = dataframes['artist']
customer = dataframes['customer']
employee = dataframes['employee']
genre = dataframes['genre']
invoice = dataframes['invoice']
invoiceline = dataframes['invoiceline']
mediatype = dataframes['mediatype']
playlist = dataframes['playlist']
playlisttrack = dataframes['playlisttrack']
track = dataframes['track']

# %% [markdown]
# # Question 2.
# Initial data examination

# %%
for table_name, df in dataframes.items():
    print(f"--- Table: {table_name} ---")
    print(f"Shape: {df.shape}")  # Display the number of rows and columns
    print(f"Columns: {df.columns.tolist()}")  # Display column names
    print(f"Data types:\n{df.dtypes}")  # Display data types
    print(f"Missing values:\n{df.isnull().sum()}")  # Display the number of missing values in each column
    print(f"Descriptive statistics:\n{df.describe(include='all')}")  # Display summary statistics
    print("\n")
# Out:
# --- Table: album ---
# Shape: (347, 3)
# Columns: ['AlbumId', 'Title', 'ArtistId']
# Data types:
# AlbumId      int64
# Title       object
# ArtistId     int64
# dtype: object
# Missing values:
# AlbumId     0
# Title       0
# ArtistId    0
# dtype: int64
# Descriptive statistics:
#            AlbumId                                              Title  \
# count   347.000000                                                347
# unique         NaN                                                347
# top            NaN  Koyaanisqatsi (Soundtrack from the Motion Pict...
# freq           NaN                                                  1
# mean    174.000000                                                NaN
# std     100.314505                                                NaN
# min       1.000000                                                NaN
# 25%      87.500000                                                NaN
# 50%     174.000000                                                NaN
# 75%     260.500000                                                NaN
# max     347.000000                                                NaN
#
#           ArtistId
# count   347.000000
# unique         NaN
# top            NaN
# freq           NaN
# mean    121.942363
# std      77.793131
# min       1.000000
# 25%      58.000000
# 50%     112.000000
# 75%     179.500000
# max     275.000000
#
#
# --- Table: artist ---
# Shape: (275, 2)
# Columns: ['ArtistId', 'Name']
# Data types:
# ArtistId     int64
# Name        object
# dtype: object
# Missing values:
# ArtistId    0
# Name        0
# dtype: int64
# Descriptive statistics:
#           ArtistId                   Name
# count   275.000000                    275
# unique         NaN                    275
# top            NaN  Philip Glass Ensemble
# freq           NaN                      1
# mean    138.000000                    NaN
# std      79.529869                    NaN
# min       1.000000                    NaN
# 25%      69.500000                    NaN
# 50%     138.000000                    NaN
# 75%     206.500000                    NaN
# max     275.000000                    NaN
#
#
# --- Table: customer ---
# Shape: (59, 13)
# Columns: ['CustomerId', 'FirstName', 'LastName', 'Company', 'Address', 'City', 'State', 'Country', 'PostalCode', 'Phone', 'Fax', 'Email', 'SupportRepId']
# Data types:
# CustomerId       int64
# FirstName       object
# LastName        object
# Company         object
# Address         object
# City            object
# State           object
# Country         object
# PostalCode      object
# Phone           object
# Fax             object
# Email           object
# SupportRepId     int64
# dtype: object
# Missing values:
# CustomerId       0
# FirstName        0
# LastName         0
# Company         49
# Address          0
# City             0
# State           29
# Country          0
# PostalCode       4
# Phone            1
# Fax             47
# Email            0
# SupportRepId     0
# dtype: int64
# Descriptive statistics:
#         CustomerId FirstName   LastName  \
# count    59.000000        59         59
# unique         NaN        57         59
# top            NaN     Frank  Gonçalves
# freq           NaN         2          1
# mean     30.000000       NaN        NaN
# std      17.175564       NaN        NaN
# min       1.000000       NaN        NaN
# 25%      15.500000       NaN        NaN
# 50%      30.000000       NaN        NaN
# 75%      44.500000       NaN        NaN
# max      59.000000       NaN        NaN
#
#                                                  Company  \
# count                                                 10
# unique                                                10
# top     Embraer - Empresa Brasileira de Aeronáutica S.A.
# freq                                                   1
# mean                                                 NaN
# std                                                  NaN
# min                                                  NaN
# 25%                                                  NaN
# 50%                                                  NaN
# 75%                                                  NaN
# max                                                  NaN
#
#                                 Address    City State Country PostalCode  \
# count                                59      59    30      59         55
# unique                               59      53    25      24         55
# top     Av. Brigadeiro Faria Lima, 2170  Prague    SP     USA  12227-000
# freq                                  1       2     3      13          1
# mean                                NaN     NaN   NaN     NaN        NaN
# std                                 NaN     NaN   NaN     NaN        NaN
# min                                 NaN     NaN   NaN     NaN        NaN
# 25%                                 NaN     NaN   NaN     NaN        NaN
# 50%                                 NaN     NaN   NaN     NaN        NaN
# 75%                                 NaN     NaN   NaN     NaN        NaN
# max                                 NaN     NaN   NaN     NaN        NaN
#
#                      Phone                 Fax                 Email  \
# count                   58                  12                    59
# unique                  58                  12                    59
# top     +55 (12) 3923-5555  +55 (12) 3923-5566  luisg@embraer.com.br
# freq                     1                   1                     1
# mean                   NaN                 NaN                   NaN
# std                    NaN                 NaN                   NaN
# min                    NaN                 NaN                   NaN
# 25%                    NaN                 NaN                   NaN
# 50%                    NaN                 NaN                   NaN
# 75%                    NaN                 NaN                   NaN
# max                    NaN                 NaN                   NaN
#
#         SupportRepId
# count      59.000000
# unique           NaN
# top              NaN
# freq             NaN
# mean        3.949153
# std         0.818403
# min         3.000000
# 25%         3.000000
# 50%         4.000000
# 75%         5.000000
# max         5.000000
#
#
# --- Table: employee ---
# Shape: (8, 15)
# Columns: ['EmployeeId', 'LastName', 'FirstName', 'Title', 'ReportsTo', 'BirthDate', 'HireDate', 'Address', 'City', 'State', 'Country', 'PostalCode', 'Phone', 'Fax', 'Email']
# Data types:
# EmployeeId             int64
# LastName              object
# FirstName             object
# Title                 object
# ReportsTo            float64
# BirthDate     datetime64[ns]
# HireDate      datetime64[ns]
# Address               object
# City                  object
# State                 object
# Country               object
# PostalCode            object
# Phone                 object
# Fax                   object
# Email                 object
# dtype: object
# Missing values:
# EmployeeId    0
# LastName      0
# FirstName     0
# Title         0
# ReportsTo     1
# BirthDate     0
# HireDate      0
# Address       0
# City          0
# State         0
# Country       0
# PostalCode    0
# Phone         0
# Fax           0
# Email         0
# dtype: int64
# Descriptive statistics:
#         EmployeeId LastName FirstName                Title  ReportsTo  \
# count      8.00000        8         8                    8   7.000000
# unique         NaN        8         8                    5        NaN
# top            NaN    Adams    Andrew  Sales Support Agent        NaN
# freq           NaN        1         1                    3        NaN
# mean       4.50000      NaN       NaN                  NaN   2.857143
# min        1.00000      NaN       NaN                  NaN   1.000000
# 25%        2.75000      NaN       NaN                  NaN   1.500000
# 50%        4.50000      NaN       NaN                  NaN   2.000000
# 75%        6.25000      NaN       NaN                  NaN   4.000000
# max        8.00000      NaN       NaN                  NaN   6.000000
# std        2.44949      NaN       NaN                  NaN   2.193063
#
#                   BirthDate             HireDate              Address  \
# count                     8                    8                    8
# unique                  NaN                  NaN                    8
# top                     NaN                  NaN  11120 Jasper Ave NW
# freq                    NaN                  NaN                    1
# mean    1964-12-10 03:00:00  2003-04-15 06:00:00                  NaN
# min     1947-09-19 00:00:00  2002-04-01 00:00:00                  NaN
# 25%     1961-05-02 00:00:00  2002-07-18 18:00:00                  NaN
# 50%     1966-08-06 00:00:00  2003-07-25 12:00:00                  NaN
# 75%     1971-03-07 06:00:00  2003-11-05 06:00:00                  NaN
# max     1973-08-29 00:00:00  2004-03-04 00:00:00                  NaN
# std                     NaN                  NaN                  NaN
#
#            City State Country PostalCode              Phone  \
# count         8     8       8          8                  8
# unique        3     1       1          8                  7
# top     Calgary    AB  Canada    T5K 2N1  +1 (403) 262-3443
# freq          5     8       8          1                  2
# mean        NaN   NaN     NaN        NaN                NaN
# min         NaN   NaN     NaN        NaN                NaN
# 25%         NaN   NaN     NaN        NaN                NaN
# 50%         NaN   NaN     NaN        NaN                NaN
# 75%         NaN   NaN     NaN        NaN                NaN
# max         NaN   NaN     NaN        NaN                NaN
# std         NaN   NaN     NaN        NaN                NaN
#
#                       Fax                   Email
# count                   8                       8
# unique                  8                       8
# top     +1 (780) 428-3457  andrew@chinookcorp.com
# freq                    1                       1
# mean                  NaN                     NaN
# min                   NaN                     NaN
# 25%                   NaN                     NaN
# 50%                   NaN                     NaN
# 75%                   NaN                     NaN
# max                   NaN                     NaN
# std                   NaN                     NaN
#
#
# --- Table: genre ---
# Shape: (25, 2)
# Columns: ['GenreId', 'Name']
# Data types:
# GenreId     int64
# Name       object
# dtype: object
# Missing values:
# GenreId    0
# Name       0
# dtype: int64
# Descriptive statistics:
#           GenreId  Name
# count   25.000000    25
# unique        NaN    25
# top           NaN  Rock
# freq          NaN     1
# mean    13.000000   NaN
# std      7.359801   NaN
# min      1.000000   NaN
# 25%      7.000000   NaN
# 50%     13.000000   NaN
# 75%     19.000000   NaN
# max     25.000000   NaN
#
#
# --- Table: invoice ---
# Shape: (412, 9)
# Columns: ['InvoiceId', 'CustomerId', 'InvoiceDate', 'BillingAddress', 'BillingCity', 'BillingState', 'BillingCountry', 'BillingPostalCode', 'Total']
# Data types:
# InvoiceId                     int64
# CustomerId                    int64
# InvoiceDate          datetime64[ns]
# BillingAddress               object
# BillingCity                  object
# BillingState                 object
# BillingCountry               object
# BillingPostalCode            object
# Total                       float64
# dtype: object
# Missing values:
# InvoiceId              0
# CustomerId             0
# InvoiceDate            0
# BillingAddress         0
# BillingCity            0
# BillingState         202
# BillingCountry         0
# BillingPostalCode     28
# Total                  0
# dtype: int64
# Descriptive statistics:
#          InvoiceId  CustomerId                    InvoiceDate  \
# count   412.000000  412.000000                            412
# unique         NaN         NaN                            NaN
# top            NaN         NaN                            NaN
# freq           NaN         NaN                            NaN
# mean    206.500000   29.929612  2023-06-26 08:05:49.514563072
# min       1.000000    1.000000            2021-01-01 00:00:00
# 25%     103.750000   15.000000            2022-03-27 00:00:00
# 50%     206.500000   30.000000            2023-06-22 12:00:00
# 75%     309.250000   45.000000            2024-09-26 06:00:00
# max     412.000000   59.000000            2025-12-22 00:00:00
# std     119.078406   17.010585                            NaN
#
#                  BillingAddress BillingCity BillingState BillingCountry  \
# count                       412         412          210            412
# unique                       59          53           25             24
# top     Theodor-Heuss-Straße 34      Berlin           CA            USA
# freq                          7          14           21             91
# mean                        NaN         NaN          NaN            NaN
# min                         NaN         NaN          NaN            NaN
# 25%                         NaN         NaN          NaN            NaN
# 50%                         NaN         NaN          NaN            NaN
# 75%                         NaN         NaN          NaN            NaN
# max                         NaN         NaN          NaN            NaN
# std                         NaN         NaN          NaN            NaN
#
#        BillingPostalCode       Total
# count                384  412.000000
# unique                55         NaN
# top                70174         NaN
# freq                   7         NaN
# mean                 NaN    5.651942
# min                  NaN    0.990000
# 25%                  NaN    1.980000
# 50%                  NaN    3.960000
# 75%                  NaN    8.910000
# max                  NaN   25.860000
# std                  NaN    4.745320
#
#
# --- Table: invoiceline ---
# Shape: (2240, 5)
# Columns: ['InvoiceLineId', 'InvoiceId', 'TrackId', 'UnitPrice', 'Quantity']
# Data types:
# InvoiceLineId      int64
# InvoiceId          int64
# TrackId            int64
# UnitPrice        float64
# Quantity           int64
# dtype: object
# Missing values:
# InvoiceLineId    0
# InvoiceId        0
# TrackId          0
# UnitPrice        0
# Quantity         0
# dtype: int64
# Descriptive statistics:
#        InvoiceLineId    InvoiceId      TrackId    UnitPrice  Quantity
# count    2240.000000  2240.000000  2240.000000  2240.000000    2240.0
# mean     1120.500000   206.868750  1717.734375     1.039554       1.0
# std       646.776623   119.134877   993.797999     0.217069       0.0
# min         1.000000     1.000000     1.000000     0.990000       1.0
# 25%       560.750000   103.000000   874.000000     0.990000       1.0
# 50%      1120.500000   207.000000  1708.000000     0.990000       1.0
# 75%      1680.250000   311.000000  2560.000000     0.990000       1.0
# max      2240.000000   412.000000  3500.000000     1.990000       1.0
#
#
# --- Table: mediatype ---
# Shape: (5, 2)
# Columns: ['MediaTypeId', 'Name']
# Data types:
# MediaTypeId     int64
# Name           object
# dtype: object
# Missing values:
# MediaTypeId    0
# Name           0
# dtype: int64
# Descriptive statistics:
#         MediaTypeId             Name
# count      5.000000                5
# unique          NaN                5
# top             NaN  MPEG audio file
# freq            NaN                1
# mean       3.000000              NaN
# std        1.581139              NaN
# min        1.000000              NaN
# 25%        2.000000              NaN
# 50%        3.000000              NaN
# 75%        4.000000              NaN
# max        5.000000              NaN
#
#
# --- Table: playlist ---
# Shape: (18, 2)
# Columns: ['PlaylistId', 'Name']
# Data types:
# PlaylistId     int64
# Name          object
# dtype: object
# Missing values:
# PlaylistId    0
# Name          0
# dtype: int64
# Descriptive statistics:
#         PlaylistId   Name
# count    18.000000     18
# unique         NaN     14
# top            NaN  Music
# freq           NaN      2
# mean      9.500000    NaN
# std       5.338539    NaN
# min       1.000000    NaN
# 25%       5.250000    NaN
# 50%       9.500000    NaN
# 75%      13.750000    NaN
# max      18.000000    NaN
#
#
# --- Table: playlisttrack ---
# Shape: (8715, 2)
# Columns: ['PlaylistId', 'TrackId']
# Data types:
# PlaylistId    int64
# TrackId       int64
# dtype: object
# Missing values:
# PlaylistId    0
# TrackId       0
# dtype: int64
# Descriptive statistics:
#         PlaylistId      TrackId
# count  8715.000000  8715.000000
# mean      4.917040  1767.081698
# std       3.476453  1023.669286
# min       1.000000     1.000000
# 25%       1.000000   888.000000
# 50%       5.000000  1773.000000
# 75%       8.000000  2652.000000
# max      18.000000  3503.000000
#
#
# --- Table: track ---
# Shape: (3503, 9)
# Columns: ['TrackId', 'Name', 'AlbumId', 'MediaTypeId', 'GenreId', 'Composer', 'Milliseconds', 'Bytes', 'UnitPrice']
# Data types:
# TrackId           int64
# Name             object
# AlbumId           int64
# MediaTypeId       int64
# GenreId           int64
# Composer         object
# Milliseconds      int64
# Bytes             int64
# UnitPrice       float64
# dtype: object
# Missing values:
# TrackId           0
# Name              0
# AlbumId           0
# MediaTypeId       0
# GenreId           0
# Composer        977
# Milliseconds      0
# Bytes             0
# UnitPrice         0
# dtype: int64
# Descriptive statistics:
#             TrackId         Name      AlbumId  MediaTypeId      GenreId  \
# count   3503.000000         3503  3503.000000  3503.000000  3503.000000
# unique          NaN         3257          NaN          NaN          NaN
# top             NaN  The Trooper          NaN          NaN          NaN
# freq            NaN            5          NaN          NaN          NaN
# mean    1752.000000          NaN   140.929489     1.208393     5.725378
# std     1011.373324          NaN    81.775395     0.580443     6.190204
# min        1.000000          NaN     1.000000     1.000000     1.000000
# 25%      876.500000          NaN    70.500000     1.000000     1.000000
# 50%     1752.000000          NaN   141.000000     1.000000     3.000000
# 75%     2627.500000          NaN   212.000000     1.000000     7.000000
# max     3503.000000          NaN   347.000000     5.000000    25.000000
#
#             Composer  Milliseconds         Bytes    UnitPrice
# count           2526  3.503000e+03  3.503000e+03  3503.000000
# unique           853           NaN           NaN          NaN
# top     Steve Harris           NaN           NaN          NaN
# freq              80           NaN           NaN          NaN
# mean             NaN  3.935992e+05  3.351021e+07     1.050805
# std              NaN  5.350054e+05  1.053925e+08     0.239006
# min              NaN  1.071000e+03  3.874700e+04     0.990000
# 25%              NaN  2.072810e+05  6.342566e+06     0.990000
# 50%              NaN  2.556340e+05  8.107896e+06     0.990000
# 75%              NaN  3.216450e+05  1.026679e+07     0.990000
# max              NaN  5.286953e+06  1.059546e+09     1.990000

# %% [markdown]
# # Question 3 , 4.
# Visualizing important variables

# %% [markdown]
# # Revenue

# %% [markdown]
# Revenue Distribution by Genre

# %%
query_genre_revenue = """
select g.Name as genre_name,SUM(il.UnitPrice * il.Quantity) AS TotalRevenue 
from invoiceline il
join track t on il.TrackId = t.TrackId
join genre g on t.GenreId = g.GenreId
group by g.Name
"""
genre_revenue_df = pd.read_sql(query_genre_revenue, engine)
genre_revenue_df = genre_revenue_df.sort_values(by='TotalRevenue', ascending=False)

plt.figure(figsize=(10, 8))
sns.set(style="whitegrid")
sns.barplot(x='TotalRevenue', y='genre_name', data=genre_revenue_df, palette='viridis', hue='genre_name', dodge=False, legend=False)
plt.title('Revenue Distribution by Genre')
plt.xlabel('Total Revenue')
plt.ylabel('Genre')
save_path = os.path.join(image_dir, '3-1.jpg')
plt.savefig(save_path)
plt.show()

# %% [markdown]
# Revenue Distribution of top 50 albums

# %%
query_album_revenue = """
SELECT SUM(il.UnitPrice * il.Quantity) AS TotalRevenue, a.Title as AlbumTitle
FROM invoice i
JOIN invoiceline il ON i.InvoiceId = il.InvoiceId
JOIN track t ON il.TrackId = t.TrackId
JOIN album a ON t.AlbumId = a.AlbumId
GROUP BY a.Title, a.AlbumId
ORDER BY 1 DESC
LIMIT 50;
"""
album_revenue_df =pd.read_sql(query_album_revenue, engine)

sns.set(style="whitegrid")
plt.figure(figsize=(15, 8))
sns.barplot(y='TotalRevenue', x='AlbumTitle', data=album_revenue_df, palette='viridis',legend=False,hue='AlbumTitle')
plt.title('Top 50 Albums by Revenue')
plt.xlabel('Album Title')
plt.ylabel('Revenue')
plt.xticks(rotation=90)
plt.tight_layout()
save_path = os.path.join(image_dir, '3-2.jpg')
plt.savefig(save_path)
plt.show()

# %% [markdown]
# Revenue Distribution of Top 50 Tracks

# %%
query_top_track="""
select il.TrackId,t.Name as TrackName,SUM(il.UnitPrice * il.Quantity) AS Revenue  from invoiceline il 
join track t on il.TrackId =t.TrackId 
group by il.TrackId ,t.Name 
order by Revenue desc
limit 50;
"""
top_track_df=pd.read_sql(query_top_track, engine)

sns.set(style="whitegrid")
plt.figure(figsize=(15, 8))
sns.barplot(x='TrackName', y='Revenue', data=top_track_df, palette='viridis',legend=False,hue='TrackName')
plt.xticks(rotation=90)
plt.title('Top 50 Tracks by Revenue')
plt.xlabel('Track Name')
plt.ylabel('Revenue')
plt.tight_layout()
save_path = os.path.join(image_dir, '3-3.jpg')
plt.savefig(save_path)
plt.show()

# %% [markdown]
# Revenue Distribution of top 20 Customer

# %%
query = """
SELECT SUM(Total) as Revenue, i.CustomerId, CONCAT(FirstName, ' ', LastName) as CustomerName
FROM invoice i
JOIN customer c ON i.CustomerId = c.CustomerId
GROUP BY i.CustomerId, CONCAT(FirstName, ' ', LastName)
limit 20;
"""
customer_revenue_df = pd.read_sql(query, engine)

sns.set(style="whitegrid")
customer_revenue_df = customer_revenue_df.sort_values(by='Revenue', ascending=False)

plt.figure(figsize=(12, 8))
barplot = sns.barplot(x='Revenue', y='CustomerName', data=customer_revenue_df, palette='viridis',legend=False,hue='CustomerName')
plt.title('Revenue Distribution by Customer')
plt.xlabel('Revenue')
plt.ylabel('Customer Name')
save_path = os.path.join(image_dir, '3-4.jpg')
plt.savefig(save_path)
plt.show()

# %% [markdown]
# # Artists

# %% [markdown]
# Artists with low track sales

# %%
query= """
with AllTrackInfo as 
(
select Count(*) as AllTrack ,ar.Name as ArtistName 
from track t
join album a on t.AlbumId = a.AlbumId
join artist ar on a.ArtistId = ar.ArtistId
group by ar.Name
)
,soldTrackInfo as 
(
select Count(DISTINCT il.TrackId) soldCount,ar.Name as ArtistName 
from invoiceline il
join track t on il.TrackId=t.TrackId
join album a on t.AlbumId = a.AlbumId
join artist ar on a.ArtistId = ar.ArtistId
group by ar.Name
)
,result as 
(
select AllTrackInfo.ArtistName,AllTrack,ifnull(soldCount,0)/AllTrack*100 SoldPercentage
,(AllTrack - ifnull(soldCount,0))/AllTrack*100 as UnsoldPercentage 
from AllTrackInfo
left join soldTrackInfo on AllTrackInfo.ArtistName=soldTrackInfo.ArtistName
)
select ArtistName,SoldPercentage,unsoldPercentage,AllTrack from result
order by 3 desc;
"""
artist_data_df = pd.read_sql(query, engine)
artist_Performance_df=artist_data_df[(artist_data_df['UnsoldPercentage']>artist_data_df['SoldPercentage'])]
artist_Performance_df.loc[:, 'ArtistName'] = artist_Performance_df['ArtistName'].apply(lambda x: x if len(x) <= 15 else x[:12] + '...')


plt.figure(figsize=(20, 10))
plt.plot(artist_Performance_df['ArtistName'], artist_Performance_df['SoldPercentage'], marker='o', label='Sold Percentage', color='green')
plt.plot(artist_Performance_df['ArtistName'], artist_Performance_df['UnsoldPercentage'], marker='o', label='Unsold Percentage', color='red')
plt.title('Sold and Unsold Track Percentage by Artist')
plt.xlabel('Artist Name')
plt.ylabel('Percentage')
plt.xticks(rotation=90)
plt.legend()
plt.tight_layout()
save_path = os.path.join(image_dir, '3-5.jpg')
plt.savefig(save_path)
plt.show()

# %% [markdown]
# Artists with over 80% track sales

# %%
artist_over_80p_sold_data_df = artist_data_df[(artist_data_df['SoldPercentage'] > 80) & (artist_data_df['AllTrack'] !=1)]
artist_over_80p_sold_data_df.loc[:, 'ArtistName'] = artist_over_80p_sold_data_df['ArtistName'].apply(lambda x: x if len(x) <= 15 else x[:12] + '...')

sns.set(style="whitegrid")
plt.figure(figsize=(15, 10))
sns.barplot(x='ArtistName', y='SoldPercentage', data=artist_over_80p_sold_data_df, color='green', label='Sold Percentage')
sns.barplot(x='ArtistName', y='UnsoldPercentage', data=artist_over_80p_sold_data_df, color='red', label='Unsold Percentage')
plt.title('Sold and Unsold Track Percentage by Artist (Sold > 80%)')
plt.xlabel('Artist Name')
plt.ylabel('Percentage')
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
save_path = os.path.join(image_dir, '3-6.jpg')
plt.savefig(save_path)
plt.show()

# %% [markdown]
# # Customer

# %% [markdown]
# Distribution of Customers by Country

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(8, 6))
sns.countplot(y=customer['Country'], order=customer['Country'].value_counts().index)
plt.title('Distribution of Customers by Country')
plt.xlabel('Number of Customers')
plt.ylabel('Country')
save_path = os.path.join(image_dir, '3-7.jpg')
plt.savefig(save_path)
plt.show()

# %% [markdown]
# # Employee

# %% [markdown]
# Total Track Sales by Employees Over the Years

# %%
query_employee_sales = """
SELECT e.EmployeeId, CONCAT(e.FirstName, ' ', e.LastName) AS Fullname, COUNT(*) AS TotalSales, YEAR(InvoiceDate) AS Year
FROM invoice i
JOIN customer c ON i.CustomerId = c.CustomerId
JOIN employee e ON c.SupportRepId = e.EmployeeId
GROUP BY e.EmployeeId, Fullname, YEAR(InvoiceDate)
ORDER BY TotalSales DESC;
"""
employee_sales_df = pd.read_sql(query_employee_sales, engine)

sns.set(style="whitegrid")
plt.figure(figsize=(15, 8))
sns.barplot(x='Year', y='TotalSales', hue='Fullname', data=employee_sales_df, palette='viridis')
plt.title('Total Track Sales by Employees Over the Years')
plt.xlabel('Year')
plt.ylabel('Total Sales')
plt.legend(title='Employee', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
save_path = os.path.join(image_dir, '3-8.jpg')
plt.savefig(save_path)
plt.show()

# %% [markdown]
# # Question 5.

# %% [markdown]
# Check Normality of data using Plots and Statistical test

# %%
# Visual Method: Histograms and QQ-Plots
def plot_histogram_and_qqplot(data, title):
    plt.figure(figsize=(12, 6))

    # Histogram
    plt.subplot(1, 2, 1)
    sns.histplot(data,bins=30, kde=True)
    plt.title(f'Histogram of {title}')

    # QQ-Plot
    plt.subplot(1, 2, 2)
    probplot(data, dist="norm", plot=plt)
    plt.title(f'QQ-Plot of {title}')
    save_path = os.path.join(image_dir, f'{title}.jpg')
    plt.savefig(save_path)
    plt.show()

# Statistical Tests
def perform_statistical_tests(data, variable_name):
    print(f"{GREEN}Statistical Tests for {variable_name}:{RESET}")

    # Shapiro-Wilk Test
    shapiro_stat, shapiro_p = shapiro(data)
    print(f"Shapiro-Wilk Test: \nStatistics={shapiro_stat}, p-value={shapiro_p}")
    alpha = 0.05
    if shapiro_p < alpha:
        print('Reject the null hypothesis: The data does not appear to be normally distributed.\n')
    else:
        print('Fail to reject the null hypothesis: The data appears to be normally distributed.\n')

    # Kolmogorov-Smirnov Test
    ks_stat, ks_p = kstest(data, 'norm', args=(data.mean(), data.std()))
    print(f"Kolmogorov-Smirnov Test:\nStatistics={ks_stat}, p-value={ks_p}")
    if ks_p < alpha:
        print('Reject the null hypothesis: The data does not appear to be normally distributed.\n')
    else:
        print('Fail to reject the null hypothesis: The data appears to be normally distributed.\n')

    # D'Agostino's K^2 Test
    dagostino_stat, dagostino_p = normaltest(data)
    print(f"D'Agostino's K^2 Test:\nStatistics={dagostino_stat}, p-value={dagostino_p}")
    if dagostino_p < alpha:
        print('Reject the null hypothesis: The data does not appear to be normally distributed.\n')
    else:
        print('Fail to reject the null hypothesis: The data appears to be normally distributed.\n')



# Plot histograms and QQ-Plots for TotalRevenue and Track Duration
plot_histogram_and_qqplot(genre_revenue_df['TotalRevenue'], 'TotalRevenue per Genre')
plot_histogram_and_qqplot(album_revenue_df['TotalRevenue'],'TotalRevenue per Album')
plot_histogram_and_qqplot(top_track_df['Revenue'],'TotalRevenue per Track')
plot_histogram_and_qqplot(customer_revenue_df['Revenue'], 'TotalRevenue per customer')
plot_histogram_and_qqplot(artist_data_df['SoldPercentage'],'Sold percentage of Artists')


# Perform statistical tests for Total and Seconds
perform_statistical_tests(genre_revenue_df['TotalRevenue'], 'TotalRevenue per Genre')
perform_statistical_tests(album_revenue_df['TotalRevenue'],'TotalRevenue per Album')
perform_statistical_tests(top_track_df['Revenue'],'TotalRevenue per Track')
perform_statistical_tests(customer_revenue_df['Revenue'], 'TotalRevenue per customer')
perform_statistical_tests(artist_data_df['SoldPercentage'],'Sold percentage of Artists')
# Out:
# Statistical Tests for TotalRevenue per Genre:
# Shapiro-Wilk Test:
# Statistics=0.5303114220012801, p-value=1.1253966042720898e-07
# Reject the null hypothesis: The data does not appear to be normally distributed.
#
# Kolmogorov-Smirnov Test:
# Statistics=0.3409993193171929, p-value=0.005398620879835336
# Reject the null hypothesis: The data does not appear to be normally distributed.
#
# D'Agostino's K^2 Test:
# Statistics=39.53796499619787, p-value=2.5968088838479216e-09
# Reject the null hypothesis: The data does not appear to be normally distributed.
#
# Statistical Tests for TotalRevenue per Album:
# Shapiro-Wilk Test:
# Statistics=0.8393431450734239, p-value=8.060205902634084e-06
# Reject the null hypothesis: The data does not appear to be normally distributed.
#
# Kolmogorov-Smirnov Test:
# Statistics=0.17876503771818997, p-value=0.07198393018409233
# Fail to reject the null hypothesis: The data appears to be normally distributed.
#
# D'Agostino's K^2 Test:
# Statistics=17.794422505192106, p-value=0.00013676981159600293
# Reject the null hypothesis: The data does not appear to be normally distributed.
#
# Statistical Tests for TotalRevenue per Track:
# Shapiro-Wilk Test:
# Statistics=0.44123717250854066, p-value=1.5732390028085984e-12
# Reject the null hypothesis: The data does not appear to be normally distributed.
#
# Kolmogorov-Smirnov Test:
# Statistics=0.5071472378892101, p-value=1.9266414222666745e-12
# Reject the null hypothesis: The data does not appear to be normally distributed.
#
# D'Agostino's K^2 Test:
# Statistics=23.653942424091806, p-value=7.30485609814563e-06
# Reject the null hypothesis: The data does not appear to be normally distributed.
#
# Statistical Tests for TotalRevenue per customer:
# Shapiro-Wilk Test:
# Statistics=0.6038495637722653, p-value=3.228656919817954e-06
# Reject the null hypothesis: The data does not appear to be normally distributed.
#
# Kolmogorov-Smirnov Test:
# Statistics=0.29317118184117075, p-value=0.051137818535583524
# Fail to reject the null hypothesis: The data appears to be normally distributed.
#
# D'Agostino's K^2 Test:
# Statistics=33.853849759781234, p-value=4.453791981796915e-08
# Reject the null hypothesis: The data does not appear to be normally distributed.
#
# Statistical Tests for Sold percentage of Artists:
# Shapiro-Wilk Test:
# Statistics=0.9012095368153674, p-value=2.241385241254217e-10
# Reject the null hypothesis: The data does not appear to be normally distributed.
#
# Kolmogorov-Smirnov Test:
# Statistics=0.147092211583076, p-value=0.0002570422342219939
# Reject the null hypothesis: The data does not appear to be normally distributed.
#
# D'Agostino's K^2 Test:
# Statistics=11.648605306874884, p-value=0.0029548639983287845
# Reject the null hypothesis: The data does not appear to be normally distributed.

# %% [markdown]
# # Question 6.

# %%
# Functions to detect and remove outliers
def detect_outliers_zscore(data, threshold=2):
    z_scores = zscore(data)
    outliers = np.abs(z_scores) > threshold
    return outliers

def detect_outliers_iqr(data):
    Q1 = np.percentile(data, 25)
    Q3 = np.percentile(data, 75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = (data < lower_bound) | (data > upper_bound)
    return outliers

def remove_outliers(data, method='zscore', threshold=2):
    if method == 'zscore':
        outliers = detect_outliers_zscore(data, threshold)
    elif method == 'iqr':
        outliers = detect_outliers_iqr(data)
    else:
        raise ValueError("Method must be 'zscore' or 'iqr'")
    cleaned_data = data[~outliers]
    return cleaned_data

# Function to plot box plots before and after removing outliers
def plot_boxplot_comparison(data, cleaned_data, title):
    plt.figure(figsize=(10, 6))
    plt.subplot(1, 2, 1)
    sns.boxplot(x=data)
    plt.title(f'{title} (Before)')

    plt.subplot(1, 2, 2)
    sns.boxplot(x=cleaned_data)
    plt.title(f'{title} (After)')
    save_path = os.path.join(image_dir, f'6_{title}.jpg')
    plt.savefig(save_path)
    plt.show()


# Remove outliers using IQR method
genre_revenue_cleaned_iqr = remove_outliers(genre_revenue_df['TotalRevenue'], method='iqr')
album_revenue_cleaned_iqr = remove_outliers(album_revenue_df['TotalRevenue'], method='iqr')
top_track_cleaned_iqr = remove_outliers(top_track_df['Revenue'], method='iqr')
customer_revenue_cleaned_iqr = remove_outliers(customer_revenue_df['Revenue'], method='iqr')
artist_data_cleaned_iqr = remove_outliers(artist_data_df['SoldPercentage'], method='iqr')

# Plot box plots before and after removing outliers (IQR method)
plot_boxplot_comparison(genre_revenue_df['TotalRevenue'], genre_revenue_cleaned_iqr, 'TotalRevenue per Genre (IQR Cleaned)')
plot_boxplot_comparison(album_revenue_df['TotalRevenue'], album_revenue_cleaned_iqr, 'TotalRevenue per Album (IQR Cleaned)')
plot_boxplot_comparison(top_track_df['Revenue'], top_track_cleaned_iqr, 'Revenue per Track (IQR Cleaned)')
plot_boxplot_comparison(customer_revenue_df['Revenue'], customer_revenue_cleaned_iqr, 'Revenue per Customer (IQR Cleaned)')
plot_boxplot_comparison(artist_data_df['SoldPercentage'], artist_data_cleaned_iqr, 'Sold Percentage of Artists (IQR Cleaned)')

# %% [markdown]
# # Question 7.

# %%
merged_df = pd.merge(invoiceline[['TrackId','UnitPrice','Quantity']], track[['TrackId','GenreId']], on='TrackId')
merged_df = pd.merge(merged_df, genre[['GenreId','Name']], on='GenreId')
merged_df['TotalRevenue'] = merged_df['UnitPrice'] * merged_df['Quantity']
grouped_data = merged_df.groupby('Name')['TotalRevenue'].sum().reset_index()
sorted_data = grouped_data.sort_values(by='TotalRevenue', ascending=False).head(3)

# %%
top_genres = sorted_data['Name'].tolist()
top_genre_data = merged_df[merged_df['Name'].isin(top_genres)]
# استخراج داده‌های مربوط به قیمت واحد برای هر ژانر
A = top_genre_data[top_genre_data['Name'] == top_genres[0]]['UnitPrice']
B = top_genre_data[top_genre_data['Name'] == top_genres[1]]['UnitPrice']
C = top_genre_data[top_genre_data['Name'] == top_genres[2]]['UnitPrice']

stat, p_value = kruskal(A, B, C)

print(f"Kruskal-Wallis Statistic: {stat}")
print(f"P-Value: {p_value}")

# تصمیم‌گیری بر اساس مقدار p
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: There is a significant difference in mean unit price among the top genres.")
else:
    print("Fail to reject the null hypothesis: There is no significant difference in mean unit price among the top genres.")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_826/1348929837.py in ?()
#       4 A = top_genre_data[top_genre_data['Name'] == top_genres[0]]['UnitPrice']
#       5 B = top_genre_data[top_genre_data['Name'] == top_genres[1]]['UnitPrice']
#       6 C = top_genre_data[top_genre_data['Name'] == top_genres[2]]['UnitPrice']
#       7
# ----> 8 stat, p_value = kruskal(A, B, C)
#       9
#      10 print(f"Kruskal-Wallis Statistic: {stat}")
#      11 print(f"P-Value: {p_value}")
#
# ~/Projects/.venv/lib/python3.10/site-packages/scipy/stats/_axis_nan_policy.py in ?(***failed resolving arguments***)
#     527                 # behavior of those would break backward compatibility.
#     528
#     529                 if sentinel:
#     530                     samples = _remove_sentinel(samples, paired, sentinel)
# --> 531                 res = hypotest_fun_out(*samples, **kwds)
#     532                 res = result_to_tuple(res)
#     533                 res = _add_reduced_axes(res, reduced_axes, keepdims)
#     534                 return tuple_to_result(*res)
#
# ~/Projects/.venv/lib/python3.10/site-packages/scipy/stats/_stats_py.py in ?(nan_policy, *samples)
#    9263     alldata = np.concatenate(samples)
#    9264     ranked = rankdata(alldata)
#    9265     ties = tiecorrect(ranked)
#    9266     if ties == 0:
# -> 9267         raise ValueError('All numbers are identical in kruskal')
#    9268
#    9269     # Compute sum^2/n for each group and sum
#    9270     j = np.insert(np.cumsum(n), 0, 0)
#
# ValueError: All numbers are identical in kruskal

# %% [markdown]
# Correlation Between Track Length and Unit Price

# %%
corr, p_value = pearsonr(track['Milliseconds']/60000, track['UnitPrice'])

print(f"Pearson Correlation Coefficient: {corr}")
print(f"P-Value: {p_value}")

alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: There is a significant correlation between track length and unit price.")
else:
    print("Fail to reject the null hypothesis: There is no significant correlation between track length and unit price.")

# Visualization
plt.figure(figsize=(8, 6))
sns.regplot(x=track['Milliseconds'] / 60000, y=track['UnitPrice'], ci=None, scatter_kws={'s': 50, 'alpha': 0.7}, line_kws={'color': 'red'})
plt.title('Relation between Track Length and Unit Price')
plt.xlabel('Track Length (minutes)')
plt.ylabel('Unit Price')

# Annotate the plot with the Pearson correlation coefficient and p-value
plt.annotate(f'Pearson r: {corr:.2f}', xy=(0.05, 0.95), xycoords='axes fraction', fontsize=12, color='blue', ha='left', va='center')
plt.annotate(f'P-Value: {p_value:.4f}', xy=(0.05, 0.90), xycoords='axes fraction', fontsize=12, color='blue', ha='left', va='center')

plt.tight_layout()
save_path = os.path.join(image_dir, 'track_length_vs_unit_price.jpg')
plt.savefig(save_path)
plt.show()
# Out:
# Pearson Correlation Coefficient: 0.9317964749112742
# P-Value: 0.0
# Reject the null hypothesis: There is a significant correlation between track length and unit price.

# %% [markdown]
# Association Between Genre and Media Type

# %%
merged_Track_genre_df = pd.merge(genre[['GenreId','Name']], track[['TrackId','GenreId','MediaTypeId']], on='GenreId')
merged_Track_genre_MediaType_df = pd.merge(merged_Track_genre_df, mediatype, on='MediaTypeId')

merged_Track_genre_MediaType_df = merged_Track_genre_MediaType_df.rename(columns={
    'Name_x': 'GenreName',
    'Name_y': 'MediaTypeName'
})

contingency_table = pd.crosstab(merged_Track_genre_MediaType_df['GenreName'], merged_Track_genre_MediaType_df['MediaTypeName'])


chi2, p, dof, ex = chi2_contingency(contingency_table)

print(f"Chi-Square Statistic: {chi2}")
print(f"P-Value: {p}")
alpha = 0.05
if p < alpha:
    print("Reject the null hypothesis: There is a significant association between genre and media type.")
else:
    print("Fail to reject the null hypothesis: There is no significant association between genre and media type.")

plot_data = merged_Track_genre_MediaType_df.groupby(['GenreName', 'MediaTypeName']).size().reset_index(name='Count')
plt.figure(figsize=(10, 10))
sns.set(style="whitegrid")
bar_plot = sns.catplot(
    data=plot_data, 
    x='GenreName', 
    y='Count', 
    hue='MediaTypeName', 
    kind='bar', 
    height=6, 
    aspect=2, 
    palette='viridis'
)
bar_plot.set_axis_labels("Genre", "Count")
bar_plot.set_xticklabels(rotation=45, horizontalalignment='right')
bar_plot.set_titles('Count of Media Types per Genre')
save_path = os.path.join(image_dir, 'Genre_vs_Mediatype.jpg')
plt.savefig(save_path)
plt.show()
# Out:
# Chi-Square Statistic: 5650.180437321978
# P-Value: 0.0
# Reject the null hypothesis: There is a significant association between genre and media type.

# %% [markdown]
# # Extra Question

# %% [markdown]
# Relationship between Track Count and Genre

# %%
track_counts_per_album_by_genre_df = (
    track
    .merge(genre, on='GenreId')
    .groupby(['AlbumId', 'Name_y'])
    .size()
    .reset_index(name='TrackCount')
    .rename(columns={'Name_y': 'GenreName'})
    .sort_values(by='TrackCount', ascending=False)
)

contingency_table = pd.crosstab(track_counts_per_album_by_genre_df['TrackCount'], track_counts_per_album_by_genre_df['GenreName'])
chi2, p, dof, expected = chi2_contingency(contingency_table)

print(f'Chi-Square Statistic: {chi2}')
print(f'P-Value: {p}')
alpha = 0.05
if p < alpha:
    print("Reject the null hypothesis: There is a significant relationship between Track Count and Genre.")
else:
    print("Fail to reject the null hypothesis: There is no significant relationship between Track Count and Genre.")

custom_palette = sns.color_palette("hsv", 25)
plt.figure(figsize=(12, 10))
sns.histplot(track_counts_per_album_by_genre_df, x='TrackCount', hue='GenreName', multiple='stack', palette=custom_palette)
plt.title('Track Counts per Album by Genre')
plt.xlabel('Track Count')
plt.ylabel('Frequency')
max_track_count = track_counts_per_album_by_genre_df['TrackCount'].max()
plt.xticks(np.arange(0, max_track_count + 1, step=1))
plt.tight_layout()
save_path = os.path.join(image_dir, '7_extra_1.jpg')
plt.savefig(save_path)
plt.show()
# Out:
# Chi-Square Statistic: 1261.9262068327364
# P-Value: 1.7480653059388465e-45
# Reject the null hypothesis: There is a significant relationship between Track Count and Genre.

# %% [markdown]
# Correlation Between Track Count and Revenue

# %%
track_count_per_album = (
    track.groupby('AlbumId')
    .size()
    .reset_index(name='TrackCount')
)

album_revenue_by_trackCount_df = (
    invoice
    .merge(invoiceline,left_on='InvoiceId',right_on='InvoiceId')
    .merge(track, left_on='TrackId', right_on='TrackId')
    .merge(album, left_on='AlbumId', right_on='AlbumId')
)
album_revenue_by_trackCount_df['Revenue'] = album_revenue_by_trackCount_df['UnitPrice_x'] * album_revenue_by_trackCount_df['Quantity']
album_revenue_by_trackCount_df=album_revenue_by_trackCount_df[['Quantity','UnitPrice_x','AlbumId','Title','Revenue']].groupby(['AlbumId', 'Title']).agg({'Revenue': 'sum'}).reset_index()
album_revenue_by_trackCount_df=album_revenue_by_trackCount_df.merge(track_count_per_album, on='AlbumId')


correlation = album_revenue_by_trackCount_df['TrackCount'].corr(album_revenue_by_trackCount_df['Revenue'])
print(f'Correlation between Track Count and Revenue: {correlation:.2f}')
album_revenue_by_trackCount_df

sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.scatterplot(x='TrackCount', y='Revenue', data=album_revenue_by_trackCount_df)
plt.title('Relation between Track Count and Revenue')
plt.xlabel('Track Count')
plt.ylabel('Revenue')
plt.tight_layout()
save_path = os.path.join(image_dir, '7_extra_2.jpg')
plt.savefig(save_path)
plt.show()
# Out:
# Correlation between Track Count and Revenue: 0.82

# %% [markdown]
# Correlation between Track Duration and Revenue of top tracks

# %%
query_Duration_of_top_track = """
with cte as (
select il.TrackId, t.Name as TrackName, SUM(il.UnitPrice * il.Quantity) AS Revenue
from invoiceline il
join track t on il.TrackId = t.TrackId
group by il.TrackId, t.Name
order by Revenue desc
limit 10)
select Revenue, Milliseconds/60000.0 as Duration
from cte
join track t on cte.TrackId = t.TrackId
"""

Duration_of_top_track_df = pd.read_sql(query_Duration_of_top_track, engine)

# Calculate the correlation coefficient
correlation = Duration_of_top_track_df['Duration'].corr(Duration_of_top_track_df['Revenue'])
print(f'Correlation between Track Duration and Revenue of top tracks: {correlation:.2f}')

# Visualization with regression line
plt.figure(figsize=(8, 6))
sns.regplot(x='Duration', y='Revenue', data=Duration_of_top_track_df, ci=None, scatter_kws={'s': 50, 'alpha': 0.7}, line_kws={'color': 'red'})
plt.title('Relation between Track Duration and Revenue')
plt.xlabel('Duration (minutes)')
plt.ylabel('Revenue')
plt.tight_layout() 
save_path = os.path.join(image_dir, '7_extra_3.jpg')
plt.savefig(save_path)
plt.show()
# Out:
# Correlation between Track Duration and Revenue of top tracks: -0.35

# %% [markdown]
# # Question 8.

# %%
track_genre_df = track.merge(genre, on='GenreId')  
track_genre_df['DurationMinutes'] = track_genre_df['Milliseconds'] / 60000  

genre_duration_stats = (  
    track_genre_df  
    .groupby('Name_y')  
    .agg(  
        AvgDuration=('DurationMinutes', 'mean'),  
        StdDev=('DurationMinutes', 'std'),  
        Count=('DurationMinutes', 'count')  
    )  
    .reset_index()  
    .rename(columns={'Name_y': 'GenreName'})  
)  

# Calculate standard error and confidence intervals for each genre  
genre_duration_stats['StdError'] = genre_duration_stats['StdDev'] / np.sqrt(genre_duration_stats['Count'])  
confidence_interval = 0.95  
z_value = stats.norm.ppf(0.5 + confidence_interval / 2)  

# Calculate Confidence Intervals for each genre  
genre_duration_stats['CI Lower'] = genre_duration_stats['AvgDuration'] - z_value * genre_duration_stats['StdError']  
genre_duration_stats['CI Upper'] = genre_duration_stats['AvgDuration'] + z_value * genre_duration_stats['StdError']  

# Overall mean and confidence interval for all genres  
mean_duration = genre_duration_stats['AvgDuration'].mean()  
std_dev_duration = genre_duration_stats['AvgDuration'].std()  
count_duration = genre_duration_stats['AvgDuration'].count()  

std_error = std_dev_duration / np.sqrt(count_duration)  
ci_lower = mean_duration - z_value * std_error  
ci_upper = mean_duration + z_value * std_error  

print(f"Mean Track Duration: {mean_duration:.2f} minutes")  
print(f"95% Confidence Interval for Overall: ({ci_lower:.2f}, {ci_upper:.2f})")  

# Visualization  
plt.figure(figsize=(14, 8))  
sns.set(style="whitegrid")  
bar_plot = sns.barplot(  
    x='GenreName',   
    y='AvgDuration',   
    data=genre_duration_stats,   
    errorbar=None  
)  

# Add error bars for individual CI  
for index, row in genre_duration_stats.iterrows():  
    plt.plot([index, index], [row['CI Lower'], row['CI Upper']], color='black')  

plt.axhline(mean_duration, color='red', linestyle='dashed', linewidth=1, label='Overall Mean')  
plt.axhline(ci_lower, color='blue', linestyle='dashed', linewidth=1, label='Overall CI Lower')  
plt.axhline(ci_upper, color='blue', linestyle='dashed', linewidth=1, label='Overall CI Upper')  

bar_plot.set_xticklabels(bar_plot.get_xticklabels(), rotation=90, horizontalalignment='right')  
plt.title('95% Confidence Interval for Average Track Duration by Genre')  
plt.xlabel('Genre')  
plt.ylabel('Average Duration (minutes)')  
plt.legend()  
plt.tight_layout()
save_path = os.path.join(image_dir, '8_1.jpg')
plt.savefig(save_path)
plt.show()
# Out:
# Mean Track Duration: 11.12 minutes
# 95% Confidence Interval for Overall: (5.28, 16.97)
# /tmp/ipykernel_826/1982666209.py:55: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   bar_plot.set_xticklabels(bar_plot.get_xticklabels(), rotation=90, horizontalalignment='right')

# %%
country_sales = (
    invoice
    .groupby('BillingCountry')
    .agg(TotalSales=('Total', 'mean'),
         Count=('Total', 'count'),
         StdDev=('Total', 'std'))
    .reset_index()
)

# Calculate standard error and confidence intervals for each country
country_sales['StdError'] = country_sales['StdDev'] / np.sqrt(country_sales['Count'])
confidence_interval = 0.95
z_value = stats.norm.ppf(0.5 + confidence_interval / 2)

# Calculate Confidence Intervals for each country
country_sales['CI Lower'] = country_sales['TotalSales'] - z_value * country_sales['StdError']
country_sales['CI Upper'] = country_sales['TotalSales'] + z_value * country_sales['StdError']

# Overall mean and confidence interval for all countries
mean_sales = country_sales['TotalSales'].mean()
std_dev_sales = country_sales['TotalSales'].std()
count_sales = country_sales['TotalSales'].count()

std_error = std_dev_sales / np.sqrt(count_sales)
ci_lower_overall = mean_sales - z_value * std_error
ci_upper_overall = mean_sales + z_value * std_error

print(f"Mean Sales (Overall): {mean_sales:.2f}")
print(f"95% Confidence Interval (Overall): ({ci_lower_overall:.2f}, {ci_upper_overall:.2f})")

# Visualization
plt.figure(figsize=(14, 8))
sns.set(style="whitegrid")

bar_plot = sns.barplot(
    x='BillingCountry',
    y='TotalSales',
    data=country_sales,
    errorbar=None
)

# Add confidence interval bars
for index, row in country_sales.iterrows():
    plt.plot([index, index], [row['CI Lower'], row['CI Upper']], color='black')

plt.axhline(mean_sales, color='red', linestyle='dashed', linewidth=1, label='Overall Mean')
plt.axhline(ci_lower_overall, color='blue', linestyle='dashed', linewidth=1, label='Overall CI Lower')
plt.axhline(ci_upper_overall, color='blue', linestyle='dashed', linewidth=1, label='Overall CI Upper')

bar_plot.set_xticklabels(bar_plot.get_xticklabels(), rotation=45, horizontalalignment='right')
plt.title('95% Confidence Interval for Total Sales by Country')
plt.xlabel('Billing Country')
plt.ylabel('Total Sales')
plt.legend()
plt.tight_layout()
save_path = os.path.join(image_dir, '8_2.jpg')
plt.savefig(save_path)
plt.show()
country_sales
# Out:
# Mean Sales (Overall): 5.72
# 95% Confidence Interval (Overall): (5.55, 5.89)
# /tmp/ipykernel_826/2291521162.py:50: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   bar_plot.set_xticklabels(bar_plot.get_xticklabels(), rotation=45, horizontalalignment='right')
#     BillingCountry  TotalSales  Count    StdDev  StdError  CI Lower   CI Upper
# 0        Argentina    5.374286      7  4.638483  1.753182  1.938112   8.810459
# 1        Australia    5.374286      7  4.638483  1.753182  1.938112   8.810459
# 2          Austria    6.088571      7  6.263371  2.367332  1.448687  10.728456
# 3          Belgium    5.374286      7  4.638483  1.753182  1.938112   8.810459
# 4           Brazil    5.431429     35  4.324263  0.730934  3.998825   6.864033
# 5           Canada    5.427857     56  4.329768  0.578590  4.293842   6.561872
# 6            Chile    6.660000      7  6.610151  2.498402  1.763221  11.556779
# 7   Czech Republic    6.445714     14  7.069362  1.889366  2.742624  10.148804
# 8          Denmark    5.374286      7  4.638483  1.753182  1.938112   8.810459
# 9          Finland    5.945714      7  4.681402  1.769404  2.477747   9.413682
# 10          France    5.574286     35  4.474917  0.756399  4.091771   7.056800
# 11         Germany    5.588571     28  4.688503  0.886044  3.851958   7.325185
# 12         Hungary    6.517143      7  7.299792  2.759062  1.109481  11.924805
# 13           India    5.789231     13  4.367395  1.211297  3.415131   8.163330
# 14         Ireland    6.517143      7  7.299792  2.759062  1.109481  11.924805
# 15           Italy    5.374286      7  4.638483  1.753182  1.938112   8.810459
# 16     Netherlands    5.802857      7  4.833938  1.827057  2.221892   9.383823
# 17          Norway    5.660000      7  5.267267  1.990840  1.758026   9.561974
# 18          Poland    5.374286      7  4.638483  1.753182  1.938112   8.810459
# 19        Portugal    5.517143     14  4.608049  1.231553  3.103344   7.930942
# 20           Spain    5.374286      7  4.638483  1.753182  1.938112   8.810459
# 21          Sweden    5.517143      7  4.674073  1.766633  2.054605   8.979681
# 22             USA    5.747912     91  4.855371  0.508981  4.750327   6.745497
# 23  United Kingdom    5.374286     21  4.400452  0.960257  3.492216   7.256355

# %%
customer_track_counts = (
    invoice
    .merge(invoiceline,on='InvoiceId')
    .groupby('CustomerId')
    .agg(TrackCount=('InvoiceLineId', 'count'))
    .reset_index()
)
customer_track_counts


track_count_stats = customer_track_counts['TrackCount'].agg(['mean', 'count', 'std'])
track_count_stats
std_error = track_count_stats['std'] / np.sqrt(track_count_stats['count'])

confidence_interval = 0.95
z_value = stats.norm.ppf(0.5 + confidence_interval / 2)

ci_lower = track_count_stats['mean'] - z_value * std_error
ci_upper = track_count_stats['mean'] + z_value * std_error


print(f"Mean Track Count: {track_count_stats['mean']:.2f}")
print(f"95% Confidence Interval: ({ci_lower:.2f}, {ci_upper:.2f})")
plt.figure(figsize=(10, 6))
plt.hist(customer_track_counts['TrackCount'], bins=30, alpha=0.7, color='blue', edgecolor='black')
plt.axvline(track_count_stats['mean'], color='red', linestyle='dashed', linewidth=1, label='Mean')
plt.axvline(ci_lower, color='black', linestyle='dashed', linewidth=1, label='95% CI Lower')
plt.axvline(ci_upper, color='black', linestyle='dashed', linewidth=1, label='95% CI Upper')
plt.title('Histogram of Track Counts Purchased by Customers')
plt.xlabel('Number of Tracks Purchased')
plt.ylabel('Frequency')
plt.legend()
plt.tight_layout()
save_path = os.path.join(image_dir, '8_3.jpg')
plt.savefig(save_path)
plt.show()
# Out:
# Mean Track Count: 37.97
# 95% Confidence Interval: (37.90, 38.03)
